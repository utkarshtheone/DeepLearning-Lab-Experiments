# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-716ef025-19d8-405b-a70d-8f2c59dc266c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-716ef025-19d8-405b-a70d-8f2c59dc266c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Automobile_data.csv to Automobile_data.csv

# %%
import pandas as pd
df=pd.read_csv("Automobile_data.csv")
df.head(10)
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
# 5          2                 ?         audi  ...       19          25  15250
# 6          1               158         audi  ...       19          25  17710
# 7          1                 ?         audi  ...       19          25  18920
# 8          1               158         audi  ...       17          20  23875
# 9          0                 ?         audi  ...       16          22      ?
#
# [10 rows x 26 columns]

# %%
df.drop('symboling',axis='columns',inplace=True)

# %%
df.head(10)
# Out:
#   normalized-losses         make fuel-type  ... city-mpg highway-mpg  price
# 0                 ?  alfa-romero       gas  ...       21          27  13495
# 1                 ?  alfa-romero       gas  ...       21          27  16500
# 2                 ?  alfa-romero       gas  ...       19          26  16500
# 3               164         audi       gas  ...       24          30  13950
# 4               164         audi       gas  ...       18          22  17450
# 5                 ?         audi       gas  ...       19          25  15250
# 6               158         audi       gas  ...       19          25  17710
# 7                 ?         audi       gas  ...       19          25  18920
# 8               158         audi       gas  ...       17          20  23875
# 9                 ?         audi       gas  ...       16          22      ?
#
# [10 rows x 25 columns]

# %%
df.tail(5)
# Out:
#     normalized-losses   make fuel-type  ... city-mpg highway-mpg  price
# 200                95  volvo       gas  ...       23          28  16845
# 201                95  volvo       gas  ...       19          25  19045
# 202                95  volvo       gas  ...       18          23  21485
# 203                95  volvo    diesel  ...       26          27  22470
# 204                95  volvo       gas  ...       19          25  22625
#
# [5 rows x 25 columns]

# %%
o1=df.groupby('make')
toyotaDf=o1.get_group('toyota')
toyotaDf
# Out:
#     normalized-losses    make fuel-type  ... city-mpg highway-mpg  price
# 150                87  toyota       gas  ...       35          39   5348
# 151                87  toyota       gas  ...       31          38   6338
# 152                74  toyota       gas  ...       31          38   6488
# 153                77  toyota       gas  ...       31          37   6918
# 154                81  toyota       gas  ...       27          32   7898
# 155                91  toyota       gas  ...       27          32   8778
# 156                91  toyota       gas  ...       30          37   6938
# 157                91  toyota       gas  ...       30          37   7198
# 158                91  toyota    diesel  ...       34          36   7898
# 159                91  toyota    diesel  ...       38          47   7788
# 160                91  toyota       gas  ...       38          47   7738
# 161                91  toyota       gas  ...       28          34   8358
# ...

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# jaguar            3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
car_Manufactureres=df.groupby('make')
priceDf=car_Manufactureres['make','price'].max()
priceDf
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                         make  price
# make
# alfa-romero      alfa-romero  16500
# audi                    audi      ?
# bmw                      bmw  41315
# chevrolet          chevrolet   6575
# dodge                  dodge   8921
# honda                  honda   9095
# isuzu                  isuzu      ?
# jaguar                jaguar  36000
# mazda                  mazda   8845
# mercedes-benz  mercedes-benz  45400
# mercury              mercury  16503
# mitsubishi        mitsubishi   9959
# nissan                nissan   9549
# peugot                peugot  18150
# plymouth            plymouth   8921
# porsche              porsche      ?
# renault              renault   9895
# saab                    saab  18620
# subaru                subaru   9960
# toyota                toyota   9989
# ...

# %%
car_Manufactureres=df.groupby('make')
mpgDf=car_Manufactureres['make','highway-mpg'].mean()
mpgDf
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                highway-mpg
# make
# alfa-romero      26.666667
# audi             24.142857
# bmw              25.375000
# chevrolet        46.333333
# dodge            34.111111
# honda            35.461538
# isuzu            36.000000
# jaguar           18.333333
# mazda            31.941176
# mercedes-benz    21.000000
# mercury          24.000000
# mitsubishi       31.153846
# nissan           32.944444
# peugot           26.636364
# plymouth         34.142857
# porsche          26.000000
# renault          31.000000
# saab             27.333333
# subaru           30.750000
# toyota           32.906250
# volkswagen       34.916667
# volvo            25.818182

# %%
carDf=df.sort_values(by=['price'])
carDf.head(5)
# Out:
#     normalized-losses    make fuel-type  ... city-mpg highway-mpg  price
# 147                89  subaru       gas  ...       25          31  10198
# 62                115   mazda       gas  ...       26          32  10245
# 40                 85   honda       gas  ...       27          33  10295
# 42                107   honda       gas  ...       25          31  10345
# 61                129   mazda       gas  ...       26          32  10595
#
# [5 rows x 25 columns]

# %%
price_stats=carDf['price'].value_counts(ascending=False)

# %%
price_stats
# Out:
# ?        4
# 9279     2
# 5572     2
# 18150    2
# 7957     2
#         ..
# 7299     1
# 6795     1
# 24565    1
# 9895     1
# 19045    1
# Name: price, Length: 187, dtype: int64

# %%
carDf.isnull().sum()
# Out:
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
carDf['price'].unique()
# Out:
# array(['10198', '10245', '10295', '10345', '10595', '10698', '10795',
#        '10898', '10945', '11048', '11199', '11245', '11248', '11259',
#        '11549', '11595', '11694', '11845', '11850', '11900', '12170',
#        '12290', '12440', '12629', '12764', '12940', '12945', '12964',
#        '13200', '13295', '13415', '13495', '13499', '13645', '13845',
#        '13860', '13950', '14399', '14489', '14869', '15040', '15250',
#        '15510', '15580', '15645', '15690', '15750', '15985', '15998',
#        '16430', '16500', '16503', '16515', '16558', '16630', '16695',
#        '16845', '16900', '16925', '17075', '17199', '17450', '17669',
#        '17710', '17950', '18150', '18280', '18344', '18399', '18420',
#        '18620', '18920', '18950', '19045', '19699', '20970', '21105',
#        '21485', '22018', '22470', '22625', '23875', '24565', '25552',
#        '28176', '28248', '30760', '31600', '32250', '32528', '34028',
# ...

# %%
carDf.shape
# Out:
# (205, 25)
